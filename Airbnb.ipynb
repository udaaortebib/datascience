# %%
# Import packages and data files
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import r2_score, mean_squared_error
#import AllTogether as t
#import seaborn as sns

listings = pd.read_csv('listings.csv')
calendar = pd.read_csv('calendar.csv')

# %%
listings
# Out:
#             id                                               name    host_id  \
# 0         3781                          HARBORSIDE-Walk to subway       4804
# 1         5506         **Special **   Private! Minutes to center!       8229
# 2         6695                         Special!! Home Away! Condo       8229
# 3        10730                     Bright 1bed facing Golden Dome      26988
# 4        10813  Back Bay Apt-blocks to subway, Newbury St, The...      38997
# 5        10986  North End (Waterfront area)  CLOSE TO MGH & SU...      38997
# 6        13247                          Back Bay studio apartment      51637
# 7        16384                Small Room in Cambridge Kendall MIT      23078
# 8        18711  The Dorset Redline | 3BR 1BA | Short walk to R...      71783
# 9        22354                 COPLEY SQ...19TH C.TWNHSE SUNNY RM      85770
# 10       29765                 Luxury suite, Moroccan furnishings     128280
# 11       40601                Private room & bath - Jamaica Plain     174986
# 12       45987                 Gorgeous Garden Studio Charlestown     205107
# 13       60029                  Room in geographical heart of Hub     255183
# 14       67774                    Corner 1 bed facing Golden Dome      26988
# 15       69369         Entire two-bedroom apartment near Longwood     255183
# 16       77681                    Waterfall Room: Bunker Hill B&B     416912
# 17      163941            * SPECIAL!* 2 bed Duplex ApT! Location!       8229
# 18      182613  Great 2BR in Boston near everything w free par...     875739
# 19      190170                   In-Law Suite w/Room to Spare :-)     841314
# 20      197727          Great Boston neighborhood , Jamaica Plain     964356
# 21      197972                Serene Studio in a Perfect Location     965697
# 22      210097                          Treetop Haven in the City    1035747
# 23      220676                Private room off the Freedom Trail.    1144302
# 24      257588                 BOSTON LUXURY FOR LESS!! NEAR BCEC    1355344
# 25      276450       19th Century Luxury | South End | 1BR 1BA #3     814298
# 26      322593     Near Hospitals, 28 Day Bking Only,OutdoorSpace    1651480
# 27      349347  Experience Past|Enjoy Present|South End 1BR 1B...     814298
# 28      400067                Private Room in Spacious Apartment1    1997048
# 29      447826                   Sweet Little House in JP, Boston    2053557
# ...        ...                                                ...        ...
# 3013  50790902              Unfurnished Private Room in Brookline  297860058
# 3014  50793260                A place of your own | 1BR in Boston  359229620
# 3015  50793314          Cozy apartment for you | 1 BR in Brighton  359229620
# 3016  50793431          Live + Work + Stay + Easy | 2BR in Boston  359229620
# 3017  50793436                                           The Andi  359229620
# 3018  50793453          Live + Work + Stay + Easy | 3BR in Boston  359229620
# 3019  50836658       Unfurnished 3-Bedroom Apartment in Brookline  297860058
# 3020  50845071          Live + Work + Stay + Easy | 1BR in Boston  359229620
# 3021  50852363   (6-2) 3Bed, 2bedroom, 2bath, balcony, South End!   21184200
# 3022  50853818      Private Room in Shared Apt near Charles River    2356643
# 3023  50854328       Furnished Room in Shared Cambridge Apartment    2356643
# 3024  50854445  Room in furnished co-living unit, near Harvard SQ    2356643
# 3025  50854559     Private Room w/ Shared BTH, near Charles River    2356643
# 3026  50867510  2 Bed with Work From Anywhere Office & Fast Wifi!  403689684
# 3027  50870667          Vintage brownstone bed and breakfast (3A)  411294872
# 3028  50873343        Stay in a place of your own | 2BR in Quincy  359229620
# 3029  50874300       Contemporary Private Room near Charles River    2356643
# 3030  50876107           Furnished Room w/ Shared BTH & Amenities    2356643
# 3031  50876792    Room in co-living Apt, short walk to Harvard SQ    2356643
# 3032  50888634     Newly Designed Loft | Fast Wifi | Pet Friendly  382451810
# 3033  50888714    Live + Work + Stay + Easy | Studio in Cambridge  359229620
# 3034  50898388          Vintage brownstone bed and breakfast (3C)  411294872
# 3035  50898544          Vintage brownstone bed and breakfast (4A)  411294872
# 3036  50898660   Vintage brownstone bed and breakfast single (3B)  411294872
# 3037  50899267             A place of your own | Studio in Boston  359229620
# 3038  50904278                                    The bright room   62116748
# 3039  50917545  Heart of Boston Beacon Hill with a best viewBo...  373675137
# 3040  50937751                            COZY 2 BED   Apartment.  158837906
# 3041  50955477            Simple, Sunny & Clean 2 BED Fenway Apt.  351555234
# 3042  50959720          Live + Work + Stay + Easy | 1BR in Boston  359229620
#
#              host_name  neighbourhood_group  neighbourhood   latitude  \
# 0                Frank                  NaN    East Boston  42.364130
# 1                Terry                  NaN        Roxbury  42.328440
# 2                Terry                  NaN        Roxbury  42.328020
# 3                 Anne                  NaN       Downtown  42.359060
# 4             Michelle                  NaN       Back Bay  42.350610
# 5             Michelle                  NaN      North End  42.363770
# 6                Susan                  NaN       Back Bay  42.351640
# 7                 Eric                  NaN    Beacon Hill  42.359560
# 8                Lance                  NaN     Dorchester  42.322120
# 9               Robert                  NaN      South End  42.344870
# 10           Elizabeth                  NaN    Charlestown  42.377540
# 11              Robert                  NaN  Jamaica Plain  42.313470
# 12                Atef                  NaN    Charlestown  42.374240
# 13            Michelle                  NaN        Roxbury  42.325460
# 14                Anne                  NaN       Downtown  42.356890
# 15            Michelle                  NaN        Roxbury  42.325460
# 16          Christiane                  NaN    Charlestown  42.378650
# 17               Terry                  NaN        Roxbury  42.328060
# 18                 Max                  NaN    Charlestown  42.377390
# 19     Fanny & Candice                  NaN     Dorchester  42.309530
# 20                Jill                  NaN  Jamaica Plain  42.313310
# 21    Chris & Kristina                  NaN  Jamaica Plain  42.315330
# 22         Maria Elena                  NaN  Jamaica Plain  42.316850
# 23              Howard                  NaN      North End  42.366140
# 24                Meri                  NaN   South Boston  42.332550
# 25              Thatch                  NaN        Roxbury  42.338550
# 26              Edward                  NaN      South End  42.342320
# 27              Thatch                  NaN        Roxbury  42.338110
# 28              ToRena                  NaN     Dorchester  42.300660
# 29              Hilary                  NaN  Jamaica Plain  42.316580
# ...                ...                  ...            ...        ...
# 3013              June                  NaN       Brighton  42.336560
# 3014           Carolyn                  NaN    East Boston  42.370055
# 3015           Carolyn                  NaN       Brighton  42.362280
# 3016           Carolyn                  NaN     Dorchester  42.324071
# 3017           Carolyn                  NaN     Dorchester  42.325217
# 3018           Carolyn                  NaN     Dorchester  42.325568
# 3019              June                  NaN       Brighton  42.335160
# 3020           Carolyn                  NaN     Dorchester  42.325700
# 3021       AirbnbQueen                  NaN      South End  42.336584
# 3022      MyBostonTrip                  NaN        Allston  42.373247
# 3023      MyBostonTrip                  NaN        Allston  42.374716
# 3024      MyBostonTrip                  NaN        Allston  42.375030
# 3025      MyBostonTrip                  NaN        Allston  42.375020
# 3026              Noah                  NaN       Back Bay  42.344281
# 3027             Lihua                  NaN         Fenway  42.349138
# 3028           Carolyn                  NaN     Dorchester  42.284528
# 3029      MyBostonTrip                  NaN        Allston  42.373881
# 3030      MyBostonTrip                  NaN        Allston  42.373426
# 3031      MyBostonTrip                  NaN        Allston  42.375146
# 3032            Albert                  NaN       Downtown  42.354306
# 3033           Carolyn                  NaN    Charlestown  42.373145
# 3034             Lihua                  NaN         Fenway  42.349089
# 3035             Lihua                  NaN         Fenway  42.348727
# 3036             Lihua                  NaN         Fenway  42.349060
# 3037           Carolyn                  NaN    East Boston  42.369918
# 3038              Anna                  NaN      Hyde Park  42.243947
# 3039              Liya                  NaN    Beacon Hill  42.361002
# 3040            Hesham                  NaN         Fenway  42.345830
# 3041            Airbnb                  NaN         Fenway  42.342299
# 3042           Carolyn                  NaN     Dorchester  42.325762
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0    -71.029910  Entire home/apt    125              32                 20
# 1    -71.095810  Entire home/apt    145               3                107
# 2    -71.093870  Entire home/apt    169               3                115
# 3    -71.062710  Entire home/apt     76              91                 32
# 4    -71.087870  Entire home/apt    106              29                  5
# 5    -71.052060  Entire home/apt    100              29                  2
# 6    -71.087520  Entire home/apt     75              91                  0
# 7    -71.069800     Private room     50              91                  0
# 8    -71.060960  Entire home/apt    111              30                 52
# 9    -71.074410     Private room    148              29                316
# 10   -71.066420  Entire home/apt    226               2                 94
# 11   -71.110820     Private room     85               7                 80
# 12   -71.060810  Entire home/apt    125              29                130
# 13   -71.088940     Private room     80               7                141
# 14   -71.062060  Entire home/apt     93              91                 45
# 15   -71.088940  Entire home/apt    100              28                120
# 16   -71.063730     Private room    140               2                 54
# 17   -71.094230  Entire home/apt    275               3                228
# 18   -71.061990  Entire home/apt    199              91                108
# 19   -71.070600  Entire home/apt     40               7                 72
# 20   -71.120610     Private room     60              30                 49
# 21   -71.110250  Entire home/apt    138               4                405
# 22   -71.108670  Entire home/apt     93               3                213
# 23   -71.052260     Private room    145               3                252
# 24   -71.041250  Entire home/apt    264               2                351
# 25   -71.079750  Entire home/apt    280              30                 94
# 26   -71.075940  Entire home/apt     90              28                409
# 27   -71.081390  Entire home/apt    200              29                111
# 28   -71.082070     Private room     60              91                 24
# 29   -71.110120     Private room     71               3                316
# ...         ...              ...    ...             ...                ...
# 3013 -71.147070     Private room     53              91                  0
# 3014 -71.043315  Entire home/apt    191              91                  0
# 3015 -71.145760  Entire home/apt    181              91                  0
# 3016 -71.063287  Entire home/apt    248              91                  0
# 3017 -71.063359  Entire home/apt    302              91                  0
# 3018 -71.063433  Entire home/apt    290              91                  0
# 3019 -71.146832  Entire home/apt    173              91                  0
# 3020 -71.062986  Entire home/apt    195              91                  0
# 3021 -71.076951  Entire home/apt    278               2                  0
# 3022 -71.125121     Private room     45              91                  0
# 3023 -71.125044     Private room     45              91                  0
# 3024 -71.126600  Entire home/apt     45              91                  0
# 3025 -71.125320     Private room     45              91                  0
# 3026 -71.083552  Entire home/apt    391               1                  0
# 3027 -71.095553     Private room    175               1                  0
# 3028 -71.037325  Entire home/apt    187              92                  0
# 3029 -71.124992     Private room     45              91                  0
# 3030 -71.125050     Private room     45              91                  0
# 3031 -71.126835     Private room     45              91                  0
# 3032 -71.057691  Entire home/apt    126               1                  0
# 3033 -71.078179  Entire home/apt    157              92                  0
# 3034 -71.096895     Private room    175               1                  0
# 3035 -71.095799     Private room    175               1                  0
# 3036 -71.097160     Private room    125               1                  0
# 3037 -71.044011  Entire home/apt    168              91                  0
# 3038 -71.130024  Entire home/apt    269               1                  0
# 3039 -71.064878  Entire home/apt    115              31                  0
# 3040 -71.102510  Entire home/apt    532               3                  0
# 3041 -71.099581  Entire home/apt    193               1                  0
# 3042 -71.062042  Entire home/apt    195              91                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 0     2021-04-30               0.29                               1
# 1     2020-05-01               0.90                               9
# 2     2019-11-02               1.37                               9
# 3     2020-04-16               0.41                               5
# 4     2020-12-02               0.18                              11
# 5     2016-05-23               0.03                              11
# 6            NaN                NaN                               2
# 7            NaN                NaN                               1
# 8     2019-10-05               1.00                              27
# 9     2019-11-04               3.13                               4
# 10    2021-05-09               0.72                               1
# 11    2021-05-30               0.72                               1
# 12    2019-12-10               0.98                               1
# 13    2019-08-13               1.26                               5
# 14    2021-04-30               1.02                               5
# 15    2019-11-09               1.00                               5
# 16    2019-11-02               2.58                               1
# 17    2019-12-30               2.36                               9
# 18    2021-05-05               1.51                               1
# 19    2021-01-16               2.01                               1
# 20    2021-05-16               0.46                               1
# 21    2021-07-06               3.77                               2
# 22    2021-07-08               2.43                               1
# 23    2021-06-10               2.33                               1
# 24    2021-07-09               3.71                               1
# 25    2021-06-05               0.88                              96
# 26    2020-07-31               4.29                               4
# 27    2019-08-04               1.22                              96
# 28    2019-08-21               0.24                               4
# 29    2021-07-05               3.25                               1
# ...          ...                ...                             ...
# 3013         NaN                NaN                              54
# 3014         NaN                NaN                              70
# 3015         NaN                NaN                              70
# 3016         NaN                NaN                              70
# 3017         NaN                NaN                              70
# 3018         NaN                NaN                              70
# 3019         NaN                NaN                              54
# 3020         NaN                NaN                              70
# 3021         NaN                NaN                              31
# 3022         NaN                NaN                              35
# 3023         NaN                NaN                              35
# 3024         NaN                NaN                              35
# 3025         NaN                NaN                              35
# 3026         NaN                NaN                              14
# 3027         NaN                NaN                               4
# 3028         NaN                NaN                              70
# 3029         NaN                NaN                              35
# 3030         NaN                NaN                              35
# 3031         NaN                NaN                              35
# 3032         NaN                NaN                              22
# 3033         NaN                NaN                              70
# 3034         NaN                NaN                               4
# 3035         NaN                NaN                               4
# 3036         NaN                NaN                               4
# 3037         NaN                NaN                              70
# 3038         NaN                NaN                               1
# 3039         NaN                NaN                               1
# 3040         NaN                NaN                              12
# 3041         NaN                NaN                               1
# 3042         NaN                NaN                              70
#
#       availability_365
# 0                  112
# 1                   46
# 2                  109
# 3                  262
# 4                  331
# 5                  314
# 6                    0
# 7                  365
# 8                  221
# 9                   90
# 10                  44
# 11                 234
# 12                 154
# 13                 111
# 14                 237
# 15                  75
# 16                 316
# 17                 129
# 18                 112
# 19                  97
# 20                  39
# 21                  17
# 22                 193
# 23                  52
# 24                 191
# 25                   0
# 26                  50
# 27                   0
# 28                 363
# 29                   0
# ...                ...
# 3013               364
# 3014               365
# 3015               365
# 3016               365
# 3017               365
# 3018               365
# 3019               364
# 3020               365
# 3021                26
# 3022               356
# 3023               356
# 3024               356
# 3025               356
# 3026               302
# 3027               344
# 3028               365
# 3029               345
# 3030               345
# 3031               345
# 3032               171
# 3033               365
# 3034               348
# 3035               356
# 3036               342
# 3037               365
# 3038               365
# 3039               314
# 3040                84
# 3041               154
# 3042               365
#
# [3043 rows x 16 columns]

# %%
def clean_listings(df):
    
    # we are going to remove all unnecessary info for our studies
    df.drop(['name','host_id', 'host_name', 'neighbourhood_group', 'minimum_nights','number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count','availability_365'], axis=1, inplace=True)
    
     # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)
    
    # Drop rows with missing salary values
    df = df.dropna(subset=['neighbourhood'], axis=0)
    
    #Create new df
    x = df['price']
    return df, x

# %%
listings_clean, P = clean_listings(listings.copy())

# %%
#Plot in order to find most expensive to cheapest neighbourhood
neighbourhood_price = listings_clean.groupby('neighbourhood')[['price']].mean()
neighbourhood_price = neighbourhood_price.reset_index()
neighbourhood_price = neighbourhood_price.sort_values(by='price',ascending=False)
ax = neighbourhood_price.plot.bar(x='neighbourhood', y='price', figsize = (15,8))

# %%
# Bar chart with the count of each neighborhood in the listings data
plt.figure(figsize=[15,15])
sns.countplot(data=listings, y='neighbourhood', order=listings['neighbourhood'].value_counts().index)
plt.xticks(rotation=90);

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110686 entries, 0 to 1110685
# Data columns (total 7 columns):
# listing_id        1110686 non-null int64
# date              1110686 non-null object
# available         1110686 non-null object
# price             1110492 non-null object
# adjusted_price    1110492 non-null object
# minimum_nights    1110686 non-null int64
# maximum_nights    1110686 non-null int64
# dtypes: int64(3), object(4)
# memory usage: 59.3+ MB

# %%
def clean_calendar(df):
    
    # Convert price from string data type to float
    df['price'] = df['price'].str.replace('$', '')
    df['price'] = df['price'].str.replace(',', '').astype(float)
    
    # Convert date from object to datetime
    df['date'] =  pd.to_datetime(df['date'], infer_datetime_format=True)

    # Drop rows with missing salary values
    df = df.dropna(subset=['price','date'], axis=0)    
    
    #Drop date outliers
    #df.drop(df[df.date > '2021-06-01'].index, inplace=True)

    return df

# %%
calendar_clean = clean_calendar(calendar.copy())

# %%
#Plot price vs date
time = calendar_clean.groupby(['date'])['price'].mean()
time = time.to_frame().reset_index()
time = time.sort_values(by='date',ascending=True)
plt.figure(figsize=(15,8))
plt.plot(time['date'],time['price'])
